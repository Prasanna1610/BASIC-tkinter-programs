# %%
from tkinter import *

root = Tk()
root.geometry('500x1000')
root.title("Job Application")

label_0 = Label(root, text="Job Application",width=20,font=("bold", 20))
label_0.place(x=10,y=53)


label_1 = Label(root, text="Name",width=20,font=("bold", 10))
label_1.place(x=10,y=130)

entry_1 = Entry(root)
entry_1.place(x=240,y=130)

label_2 = Label(root, text="Email",width=20,font=("bold", 10))
label_2.place(x=10,y=180)

entry_2 = Entry(root)
entry_2.place(x=240,y=180)

label_3 = Label(root, text="Education",width=20,font=("bold", 10))
label_3.place(x=10,y=230)
var = IntVar()
Radiobutton(root, text="12th",padx = 5, variable=var, value=1).place(x=235,y=230)
Radiobutton(root, text="UG",padx = 20, variable=var, value=2).place(x=290,y=230)

label_4 = Label(root, text="Address",width=20,font=("bold", 10))
label_4.place(x=10,y=280)

list1 = ['Canada','India','UK','Nepal','Iceland','South Africa'];
c=StringVar()
droplist=OptionMenu(root,c, *list1)
droplist.config(width=15)
c.set('select a country')
droplist.place(x=240,y=280)

label_4 = Label(root, text="Phone Number",width=20,font=("bold", 10))
label_4.place(x=10,y=330)
var1 = IntVar()
Checkbutton(root, text="+91", variable=var1).place(x=235,y=330)
var2 = IntVar()
Checkbutton(root, text="something else", variable=var2).place(x=290,y=330)

label_5 = Label(root, text="What are your hobbies?",width=20,font=("bold", 10))
label_5.place(x=10,y=380)

entry_5 = Entry(root)
entry_5.place(x=260,y=380)

label_6 = Label(root, text="Employment Details",width=20,font=("bold", 20))
label_6.place(x=10,y=420)

label_7 = Label(root, text="Company Name",width=20,font=("bold", 10))
label_7.place(x=10,y=480)

entry_7 = Entry(root)
entry_7.place(x=260,y=480)

label_8 = Label(root, text="Job Title",width=20,font=("bold", 10))
label_8.place(x=10,y=530)

entry_8 = Entry(root)
entry_8.place(x=260,y=530)

label_9 = Label(root, text="How long ?",width=20,font=("bold", 10))
label_9.place(x=10,y=580)

entry_9 = Entry(root)
entry_9.place(x=260,y=580)

label_6 = Label(root, text="Reference #1",width=20,font=("bold", 20))
label_6.place(x=10,y=620)

label_7 = Label(root, text="Name",width=20,font=("bold", 10))
label_7.place(x=10,y=680)

entry_7 = Entry(root)
entry_7.place(x=260,y=680)

label_8 = Label(root, text="Phone",width=20,font=("bold", 10))
label_8.place(x=10,y=720)

entry_8 = Entry(root)
entry_8.place(x=260,y=720)

label_9 = Label(root, text="Reference #2",width=20,font=("bold", 20))
label_9.place(x=10,y=740)

label_10 = Label(root, text="Name",width=20,font=("bold", 10))
label_10.place(x=10,y=790)

entry_10 = Entry(root)
entry_10.place(x=260,y=790)

label_11 = Label(root, text="Phone",width=20,font=("bold", 10))
label_11.place(x=10,y=830)

entry_11 = Entry(root)
entry_11.place(x=260,y=830)

Button(root, text='Apply',width=20,bg='brown',fg='white').place(x=180,y=900)

root.mainloop()
